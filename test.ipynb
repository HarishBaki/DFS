# %%
import xarray as xr
import numpy as np

from herbie import Herbie
import fsspec

# %%
H = Herbie(
    "2018-03-19 00:00",
    model="rtma",
    product="anl",
    fxx=0,
    priority='aws'
)
H.inventory()
# Out:
# ✅ Found ┊ model=rtma ┊ product=anl ┊ 2018-Mar-19 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
#     grib_message  start_byte    end_byte              range reference_time  \
# 0              1           0   7490117.0          0-7490117     2018-03-19
# 1              2     7490118  14980235.0   7490118-14980235     2018-03-19
# 2              3    14980236  21065992.0  14980236-21065992     2018-03-19
# 3              4    21065993  27151749.0  21065993-27151749     2018-03-19
# 4              5    27151750  32769385.0  27151750-32769385     2018-03-19
# 5              6    32769386  38387021.0  32769386-38387021     2018-03-19
# 6              7    38387022  45409019.0  38387022-45409019     2018-03-19
# 7              8    45409020  51026655.0  45409020-51026655     2018-03-19
# 8              9    51026656  56176170.0  51026656-56176170     2018-03-19
# 9             10    56176171  61793806.0  56176171-61793806     2018-03-19
# ...
